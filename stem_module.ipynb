# %%
import numpy as np 
import pandas as pd
import fasttext
import fasttext.util
import random
from itertools import permutations,combinations
from numpy.linalg import norm
import math
import random
from gensim.models import KeyedVectors

# %%
def loadModel(keyword):
    """   
    Parameters:
        keyword: string
            If keyword which is fasttext pre-trained model path or name of model such as "cc.tr.300.bin" is provided, 
            fasttext model can be used for further operations.
    Returns:
        object:
            If pre-trained model name is provided, returns fasttext model including word embedding vectors can be used for
            further operations.
            
    NOTE: if you have the model. It should be in the same folder with your python notebook.
    """   
    return fasttext.load_model(keyword)

# %%
def getWordList(keyword):
    """   
    Parameters:
        keyword: string
            If keyword which has file path or name of file is provided, word list is  
            If matrix is not provided, it is the matrix for which pairwise cosine
            similarity between rows will be calculated. For example: getWordList("words2.txt") 
    
    Returns:
        array_like
            If word list is provided, returns an array of word list including each word in the file.
    """    
    word_list= pd.read_csv(keyword)
    word_list=np.array(word_list).flatten()
    return word_list

# %%
def get_word_vectors(word_list, ft):
    """   
    Parameters:
        word_list: array_like
            If word list is provided in the form of numpy array, words in the list can be transformed word embbedings 
            (ie. word vectors) by fasttext model. 
        ft: object
            If the trained or pre-trained fasttext model is provided, word embeddings of word list can be prepared.
    
    Returns:
        array_like
            If word list is provided, returns word vectors of the list in the form of numpy array.
    """    
    return np.array(list(map(ft.get_word_vector, word_list)))

# %%
def cos_similarity_function(vector_or_matrix_1, matrix=None):
    """
    Calculate cosine similarity between a vector and all rows of a matrix
    or pairwise cosine similarity between all rows of a matrix.
    
    Parameters:
        vector_or_matrix_1: array_like
            If matrix is provided, it is the vector for which cosine similarity
            will be calculated against all rows of the matrix.
            If matrix is not provided, it is the matrix for which pairwise cosine
            similarity between rows will be calculated.
        
        matrix: array_like, optional
            The matrix against which cosine similarity will be calculated.
            If not provided, pairwise cosine similarity will be calculated
            between all rows of vector_or_matrix_1.
    
    Returns:
        array_like
            If matrix is provided, returns an array of cosine similarities between
            the vector and each row of the matrix.
            If matrix is not provided, returns a matrix of pairwise cosine similarities
            between all rows of the vector_or_matrix_1.
    """
    if matrix is None:
        matrix = vector_or_matrix_1
        return np.dot(matrix, matrix.T) / (np.linalg.norm(matrix, axis=1)[:, np.newaxis] * np.linalg.norm(matrix, axis=1))
    else:
        vector = vector_or_matrix_1
        return np.dot(vector, matrix.T) / (np.linalg.norm(vector) * np.linalg.norm(matrix, axis=1))

# %%
if __name__ == "__main__":

    ft = loadModel(r'cc.tr.300.bin') 
    word_list= getWordList("words2.txt")

# %%
if __name__ == "__main__":
    vectors = get_word_vectors(word_list, ft)
    word_distances = cos_similarity_function(vectors)

# %%
def cosine_similarity(vector1, vector2):
    """   
    Parameters:
        vector1: array_like
            If word vector is provided in numpy array form, cosine similarity can be estimated with regard to other word vector.         vector2: array_like
        vector2: array_like
            If word vector is provided in numpy array form, cosine similarity can be estimated with regard to other word vector.
    Returns:
        float
            If both of word vectors provided, returns cosine similarity result.
    """ 
    
    
    dot_product = np.dot(vector1, vector2)
    norm_1 = np.linalg.norm(vector1)
    norm_2 = np.linalg.norm(vector2)
    return dot_product / (norm_1 * norm_2)

# %%
def generate_one_list(model_name,word_distances,word_list,size_of_list=12,cosine_similarity_value=0.30):
    """   
    Parameters:
        word_distances: array_like
            If word distances which was generated with "cos_similarity_function" function is provided in numpy array form, 
            word distances can be used to estimated the furthest item with regard to cosine similarity value parameter.
        word_list: array_like
            If word list is provided in numpy array form, dissimlar word list is generated from the given word list.
        size_of_list: int, optinal
            If size of list is provided, a dissimilar word list is generated with number of items which is assigned.
        cosine_similartiy_value: float, optinal
            If cosine similarity value is provided cosine similarity value of words will not be higher than assigned
            cosine similarity value. If any cosine similary value is  in the dissimilar word list
    Returns:
        array_like
            If distances between words, word list in the form of numpy array and provided, returns dissimilar list determined 
            number  of  items with regard to cosine similarity value.
        
    """  
    
    temp1=[]
    temp2=[]
    u=[]
    temp1.append(word_list[np.argpartition(word_distances[random.randint(0,len(word_list))],
                                                                random.randint(0,5))[random.randint(0,5)]])
   
    while True:
        if (len(u)==size_of_list):
            break
        a= random.randint(0,len(word_list))
        b= random.randint(0,5)
        
        try:
            index=np.argpartition(word_distances[a], b)[b]
        except:
            print("index hatası")
        else:
            index=np.argpartition(word_distances[a], b)[b]   
            temp1.append(word_list[index])
            for a,b in combinations(temp1,2):
                if(cosine_similarity_value<cosine_similarity(model_name[a],model_name[b])):
                    temp2.append(a)
            u=list(set(temp1) - set(temp2))
    return u

# %%
if __name__ == "__main__":
    res= generate_one_list(ft,word_distances,word_list)
    res=[]
    i=0
    while i<12:
        res.append(generate_one_list(ft,word_distances,word_list,20))
        i=i+1
    print(res)
# Out:
# [['yorum', 'abaküs', 'ücret', 'muson', 'cennet', 'maytap', 'nakavt', 'külhan', 'pusu', 'patron', 'güney', 'kapüşon', 'kuşku', 'çerçeve', 'bitkin', 'ünite', 'hayta', 'pide', 'harita', 'gezgin'], ['ağıl', 'peşinat', 'ibre', 'borçlu', 'içgüdü', 'uyarı', 'maytap', 'zakkum', 'dede', 'tokluk', 'hayret', 'muhbir', 'cadde', 'slogan', 'madalya', 'pide', 'avare', 'kasnak', 'yörünge', 'yağcılık'], ['aykırı', 'abaküs', 'abajur', 'peşinat', 'payda', 'geçerlik', 'sinsi', 'ağıt', 'kapüşon', 'aziz', 'enginar', 'semer', 'sakatlık', 'tabu', 'kolonya', 'lehçe', 'punto', 'acente', 'avare', 'başkent'], ['hısım', 'muson', 'teke', 'monitör', 'şafak', 'bağnaz', 'indirim', 'öncülük', 'koridor', 'takoz', 'sancak', 'abartı', 'atlet', 'iğde', 'çıkıntı', 'aforoz', 'dipnot', 'çeyiz', 'gezgin', 'deneyim'], ['sezon', 'abaküs', 'haz', 'çehre', 'teke', 'noksan', 'çekiç', 'öncülük', 'kepenk', 'yavru', 'manken', 'dipnot', 'memur', 'punto', 'bayi', 'çelenk', 'izlenim', 'aktarım', 'pomat', 'zılgıt'], ['sezon', 'şalter', 'yorum', 'abaküs', 'payda', 'ağırlama', 'dede', 'tiryaki', 'sürpriz', 'sazlık', 'kadeh', 'manken', 'imza', 'sanık', 'külot', 'hayta', 'acente', 'ibare', 'garanti', 'afiyet'], ['abajur', 'haber', 'payda', 'muson', 'prensip', 'ibraz', 'indirim', 'hain', 'kapüşon', 'gün', 'fuar', 'pense', 'muhbir', 'çalışkan', 'röfle', 'sahtekarlık', 'çelenk', 'övgü', 'ücra', 'afiyet'], ['aciliyet', 'ihmal', 'gram', 'geçerlik', 'uzunluk', 'brüt', 'gıcırtı', 'enginar', 'manken', 'imza', 'atom', 'boğa', 'kanun', 'lehçe', 'sanık', 'çöküş', 'acente', 'ibare', 'avare', 'yağcılık'], ['kopya', 'abaküs', 'haber', 'iplik', 'muhbir', 'ibre', 'etken', 'muson', 'monoton', 'zakkum', 'sinsi', 'indirim', 'rakam', 'övgü', 'pomat', 'sırdaş', 'hoşnut', 'merak', 'kapüşon', 'afiyet'], ['yorum', 'urgan', 'benzin', 'peşinat', 'bilgin', 'itiraz', 'adele', 'nakavt', 'şafak', 'tabure', 'gün', 'muhbir', 'şiddetli', 'ülkü', 'çirkinlik', 'uyum', 'ibare', 'hoşnut', 'cılık', 'afiyet'], ['ebleh', 'oynaş', 'muson', 'turizm', 'şafak', 'dudak', 'kapüşon', 'acele', 'tortu', 'kalori', 'manken', 'mızrap', 'kolonya', 'punto', 'sırdaş', 'yatkın', 'yörünge', 'ücra', 'kimyon', 'dizgin'], ['tütün', 'abaküs', 'borçlu', 'ağırlama', 'adak', 'garson', 'soba', 'otoban', 'cansız', 'sülün', 'muhbir', 'içtenlik', 'takip', 'hayta', 'esir', 'ibare', 'fobi', 'ücra', 'zılgıt', 'alıntı']]

# %%
# delete repeated items
def unique_values_in_list_of_lists(word_list):
    """   
    Parameters:
        word_list: array_like
            If word list is provided in numpy array form, dissimlar word list is generated from the given word list.

    Returns:
        array_like
            If distances between words, word list in the form of numpy array and provided, returns dissimilar list determined 
            number  of  items with regard to cosine similarity value.
        
    """  
    result=[]
    result.append(list(set(x for l in word_list for x in l)))
    return result

# %%
#get nearest
def generate_similar_words(word_list,word_distances,size_of_list=12,print_values=True):

    """   
    Parameters:
        word_list: array_like
            If word list is provided in numpy array form, simlar word list is generated from the given word list.
        word_distances: array_like
            If word distances which was generated with "cos_similarity_function" function is provided in numpy array form, 
            word distances can be used to estimated the nearest items.
        size_of_list: int, optinal
            If size of list is provided, a similar word list is generated with number of items which is assigned.
        print_values: bool, optinal
            If print_values paramater is set true, only values of dictonary is returned 
    Returns:
        array_like
            If print value is assigned true and word list, distances between words 
            in the form of numpy array and provided, returns similar list determined number  of  items in form of list.
        dictionary_like
            If print value is assigned false and word list, distances between words 
            in the form of numpy array and provided, returns similar list determined number  of  items in form of dictionary.            
            
    """  
    
    indices = np.apply_along_axis(lambda x: np.argsort(x, axis=0)[-size_of_list:-1], 1, word_distances)
    distant_words = np.apply_along_axis(lambda x:word_list[x], 1, indices)
    dist_words_dict = dict(zip(word_list, distant_words.tolist()))
    if print_values==True:
        result= list(dist_words_dict.values())
        return [item for sublist in result for item in sublist]
    else:
        return list(dist_words_dict.values())

# %%
if __name__ == "__main__":
    print(generate_similar_words(word_list,word_distances,12,print_values=False))
# Out:
# [['çanta', 'vitrin', 'kolye', 'ayna', 'tabure', 'masa', 'dolap', 'mobilya', 'yastık', 'saksı', 'lamba'], ['resim', 'çömlek', 'çekiç', 'tahta', 'kağıt', 'ibrik', 'marangoz', 'kerpeten', 'çubuk', 'satranç', 'matematik'], ['uyku', 'açlık', 'denge', 'oynaş', 'çılgınlık', 'koşu', 'afallama', 'ağırlık', 'tekme', 'üşenme', 'acıkma'], ['eleştiri', 'rezalet', 'sahtekarlık', 'rakam', 'tuhaflık', 'çılgınlık', 'fazlalık', 'espri', 'haksızlık', 'ayıp', 'yalan'], ['hekim', 'kadın', 'gaddar', 'beceri', 'mühendis', 'marangoz', 'pilot', 'cesur', 'nişancı', 'gönüllü', 'asker'], ['hata', 'davet', 'aciliyet', 'itiraz', 'doğru', 'titiz', 'karar', 'ihmal', 'çabuk', 'ısrar', 'telaş'], ['hekim', 'fuar', 'rehber', 'lokanta', 'tekne', 'liman', 'gemi', 'otel', 'seyahat', 'bayi', 'turizm'], ['tatlı', 'ağrı', 'afallama', 'bunaltı', 'yorgunluk', 'yemek', 'abanma', 'uyku', 'sinirlilik', 'açlık', 'tokluk'], ['zalimlik', 'içtenlik', 'hüzün', 'üzüntü', 'korku', 'affetme', 'ağrı', 'acılık', 'sevgi', 'vicdan', 'şefkat'], ['hasret', 'elem', 'bunaltı', 'üzüntü', 'zorluk', 'koku', 'ağrı', 'hüzün', 'acıma', 'sıkıntı', 'lezzet'], ['gizlilik', 'felaket', 'zorluk', 'afet', 'zayıflık', 'uygunluk', 'sıkıntı', 'sorun', 'tuhaflık', 'tehlike', 'önem'], ['uyku', 'bunaltı', 'yorgunluk', 'yalnızlık', 'korku', 'acıkma', 'fakirlik', 'sefalet', 'kıtlık', 'tokluk', 'yoksulluk'], ['huzur', 'namus', 'devlet', 'insanlık', 'iyilik', 'düzen', 'refah', 'barış', 'ahlak', 'vicdan', 'hukuk'], ['iyilik', 'ağıl', 'ibrik', 'heykel', 'hayvan', 'bayram', 'koç', 'dua', 'çömlek', 'mezar', 'ibadet'], ['serseri', 'haydut', 'deli', 'çocuk', 'katil', 'kral', 'erkek', 'arkadaş', 'patron', 'kız', 'kadın'], ['tekrar', 'hakim', 'yatkın', 'taklit', 'öncülük', 'rahat', 'bağımlı', 'çabuk', 'aşina ', 'alışkın', 'uyum'], ['varlık', 'sadakat', 'ahlak', 'şefkat', 'saygı', 'davranış', 'sevgi', 'inanç', 'varoluş', 'bağlılık', 'anlayış'], ['kalp', 'omuz', 'beyin', 'mide', 'iskelet', 'vücut', 'damar', 'kemik', 'bilek', 'bacak', 'kas'], ['araç', 'gün', 'erkek', 'ünite', 'kamyon', 'standart', 'tabanca', 'dönüm', 'gram', 'kutu', 'tane'], ['çığlık', 'kapı', 'önem', 'dönüm', 'aşağı', 'cesur', 'başlangıç', 'imza', 'basamak', 'somut', 'doğru'], ['eczane', 'sistem', 'hedef', 'anahtar', 'ulaşım', 'referans', 'belge', 'rehber', 'bilgi', 'faks', 'harita'], ['idare', 'eczane', 'hukuk', 'cami', 'okul', 'büro', 'adalet', 'müftülük', 'hastane', 'polis', 'mahkeme'], ['baba', 'tilki', 'anne', 'hırsız', 'haydut', 'serseri', 'çalışkan', 'hayta', 'kız', 'çocuk', 'haşarı'], ['bunalım', 'ağrı', 'terslik', 'çöküş', 'telaş', 'acıkma', 'hırçınlık', 'yorgunluk', 'tuhaflık', 'bunaltı', 'sinirlilik'], ['fakirlik', 'aciliyet', 'iklim', 'hasar', 'yoksulluk', 'tehlike', 'doğal', 'kaza', 'kıtlık', 'yangın', 'felaket'], ['üşenme', 'sevgi', 'adalet', 'sadakat', 'davranış', 'zalimlik', 'şefkat', 'iyilik', 'hata', 'özür', 'acıma'], ['heykel', 'yazı', 'sergi', 'dergi', 'film', 'tanıtım', 'bayrak', 'fotoğraf', 'resim', 'slogan', 'reklam'], ['reçel', 'huzur', 'neşe', 'iyilik', 'yemek', 'şeker', 'tatlı', 'mutluluk', 'salata', 'selam', 'lezzet'], ['taklit', 'ihbar', 'hoşnut', 'ısrar', 'davet', 'sahtekarlık', 'affetme', 'dayak', 'suçlu', 'itiraz', 'küfür'], ['sigara', 'çay', 'ipek', 'ilaç', 'şeker', 'kimyon', 'viski', 'pamuk', 'tütün', 'alkol', 'içki'], ['saksı', 'bahçe', 'zeytin', 'toprak', 'hayvan', 'odun', 'çiçek', 'ahşap', 'meyve', 'orman', 'bitki'], ['düzen', 'köy', 'mafya', 'mülk', 'zalimlik', 'gelenek', 'külhan', 'saray', 'devlet', 'haraç', 'yağcılık'], ['başlangıç', 'namaz', 'acıkma', 'karanlık', 'yaşlılık', 'güneş', 'siyah', 'gündüz', 'öğlen', 'şafak', 'yatsı'], ['mağara', 'sazlık', 'bahçe', 'konak', 'köy', 'arsa', 'yuva', 'arazi', 'tarla', 'otlak', 'barınak'], ['görüşme', 'turizm', 'hizmet', 'konfor', 'davet', 'seyahat', 'eğlence', 'düğün', 'tören', 'yemek', 'misafir'], ['fazlalık', 'basınç', 'güç', 'denge', 'omuz', 'değer', 'ivme', 'uzunluk', 'kuvvet', 'önem', 'hacim'], ['dua', 'duygulu', 'ıslık', 'cenaze', 'mezar', 'lirik', 'zılgıt', 'hüzün', ' ...

# %% [markdown]
# ## Diagnosis:

# %%
def show_diagnosis(similars_word2vec,word2vec_model,show_cos_values=True):
    """   
    Parameters:
        word_list: array_like
            If word list is provided in numpy array form, cosine similarity of combination of items of given list.
    Returns:
        array_like
            If word list, distances between words in the form of numpy array and provided, returns similar list determined 
            number  of  items.
    NOTE: before using show_diagnosis function you must 
    """      
    similarities = []
    for index in range(len(similars_word2vec)):
        current_similarity = []  
        for a, b in combinations(similars_word2vec[index], 2):
            similarity = sm.cosine_similarity(word2vec_model[a], word2vec_model[b])
            if(show_cos_values==True):
                current_similarity.append((a, b, similarity))
            else:
                 current_similarity.append((a, b))
        similarities.append(current_similarity)
    return similarities

# %% [markdown]
# ## Word2Vec

# %%
def loadword2vecmodel(keyword):
    """   
    Parameters:
        keyword: string
            If keyword which is fasttext pre-trained model path or name of model such as "trmodelword2vec.bin" is provided, 
            word2vec model can be used for further operations.
    Returns:
        object:
            If pre-trained model name is provided, returns word2vec model including word embedding vectors can be used for
            further operations.
            
    NOTE: if you have the model. It should be in the same folder with your python notebook.
    """   
    return KeyedVectors.load_word2vec_format(keyword, binary=True)

# %%
def word2vec_checkword_list(word_list,word2vec_model):
    """   
    Parameters:
        word_list: list
            If word list is provided for the word2vec model, it will be controlled to check whether word list items in
            word2vec model's corpus and word list.
        word2vec_model: object
            If keyword which is word2vec pre-trained model path or name of model is provided, it will be controlled to check whether word list items in
            word2vec model's corpus and word list.
    Returns:
        word2vec_word_list: list
            If pre-trained model name and word list are provided, returns a list including common items that word list and word2vec corpus.
            
    NOTE: if you have the model. It should be in the same folder with your python notebook.
    """   
    res_word2vec=[]
    word2vec_word_list=[]
    for i in word_list:
        if i in word2vec_model:
            res_word2vec.append((i,word2vec_model[i]))
            word2vec_word_list.append(i)

        else:
            continue
    word2vec_word_list= np.array(word2vec_word_list)  
    return word2vec_word_list

# %% [markdown]
# ## Save results as .txt File

# %%
def save_results(filename,liste):
    """   
    Parameters:
        filename: string
            If filename is provided in string form, the name of the file is named with filename.
        liste: list
            If list is provided, list items are write a .txt file.

    Returns:
        .txt file
            If filename, and number of lists are provided, it returns grouped lists.
    """ 
    with open(filename, 'w') as file:
        for items in liste[:]:  
            for i in range(len(items)):
                file.write(str(items[i]) + "\n")

# %% [markdown]
# ## Creating and Grouping Lists

# %%
def making_list_and_print(word_list, num_of_lists=20, write_lists= False):
    """   
    Parameters:
        word_list: array_like
            If word list is provided in numpy array form, cosine similarity of combination of items of given list.
        num_of_lists: int, optional
            If number of lists is provided, it groups with regard to items given number of lists.

    Returns:
        array_like
            If word list, and number of lists are provided, it returns grouped lists.
    NOTE: before using show_diagnosis function you must 
    """       
    res = []
    for i in range(0, len(word_list), num_of_lists):
        temp = word_list[i:i+num_of_lists]
        res.append(temp)
    if write_lists== True:
        with open("result_list.txt", "w") as output:
            output.write(str(gruplu_listeler))
    else:   
        return res

# %%
# Örnek kullanım:
if __name__ == "__main__":
    item_listesi = ["item" + str(i) for i in range(1, 161)]

    gruplu_listeler = making_list_and_print(word_list)

    # Her 20'li grup için ayrı ayrı listeleri ekrana yazdırma
    for index, grup in enumerate(gruplu_listeler):
        print(f"Grup {index+1}: {grup}")
# Out:
# Grup 1: ['abajur' 'abaküs' 'abanma' 'abartı' 'acemi' 'acele' 'acente' 'acıkma'
#  'acıma' 'acılık' 'aciliyet' 'açlık' 'adalet' 'adak' 'adam' 'adapte'
#  'adayış' 'adele' 'adet' 'adım']
# Grup 2: ['adres' 'adliye' 'afacan' 'afallama' 'afet' 'affetme' 'afiş' 'afiyet'
#  'aforoz' 'afyon' 'ağaç' 'ağalık' 'ağarma' 'ağıl' 'ağırlama' 'ağırlık'
#  'ağıt' 'ağız' 'ağrı' 'ahlak']
# Grup 3: ['ahşap' 'aile' 'ajan' 'akıl' 'akın' 'akım' 'akran' 'aktarım' 'alan'
#  'alet' 'alın' 'alıntı' 'alışkın' 'alkol' 'alt' 'altın' 'amaç' 'anahtar'
#  'anarşist' 'anlayış']
# Grup 4: ['anne' 'anten' 'araba' 'araç' 'araştırma' 'arazi' 'arkadaş' 'arsa'
#  'asker' 'aşağı' 'aşina ' 'atak' 'atık' 'atkı' 'atlet' 'atmosfer' 'atom'
#  'avare' 'avuç' 'avukat']
# Grup 5: ['ayakkabı' 'ayıp' 'aykırı' 'ayna' 'azim' 'aziz' 'baba' 'baca' 'bacak'
#  'bagaj' 'bağımlı' 'bağlılık' 'bağnaz' 'bahar' 'bahçe' 'bakır' 'balık'
#  'balkon' 'balon' 'banyo']
# Grup 6: ['barınak' 'barış' 'barut' 'başak' 'başarı' 'başıboş' 'başkent'
#  'başlangıç' 'başvuru' 'basamak' 'basık' 'basınç' 'baskı' 'baskın' 'bayi'
#  'bayrak' 'bayram' 'beceri' 'bela' 'belde']
# Grup 7: ['belge' 'bencil' 'benzin' 'berber' 'beton' 'beyaz' 'beyin' 'bezgin'
#  'biber' 'bilek' 'bilezik' 'bilgi' 'bilgin' 'bilim' 'bilişim' 'bina'
#  'birey' 'bisiklet' 'bitki' 'bitkin']
# Grup 8: ['bıçak' 'blok' 'böcek' 'bodrum' 'boğa' 'boğaz' 'bölüm' 'borçlu' 'boru'
#  'boya' 'boza' 'brüt' 'bulgu' 'bulut' 'bunalım' 'bunaltı' 'büro' 'büyü'
#  'buz' 'çabuk']
# Grup 9: ['cadde' 'çağrı' 'çalıntı' 'çalışkan' 'çamaşır' 'cam' 'cami' 'cansız'
#  'çanta' 'çare' 'çay' 'çehre' 'ceket' 'çekiç' 'çekirdek' 'çekmece'
#  'çelenk' 'cenaze' 'cenin' 'cennet']
# Grup 10: ['çerçeve' 'cesur' 'cevap' 'çeviri' 'çevre' 'çeyiz' 'çeyrek' 'çiçek'
#  'cihaz' 'çikolata' 'cila' 'cinayet' 'çirkinlik' 'cisim' 'çığlık'
#  'çıkıntı' 'çılgınlık' 'cıva' 'cılık' 'çocuk']
# Grup 11: ['çöküş' 'çömlek' 'çöplük' 'çorap' 'çubuk' 'çukur' 'dağ' 'daire' 'damar'
#  'damla' 'dans' 'dava' 'davet' 'davranış' 'dayak' 'dede' 'dedektif'
#  'define' 'değer' 'deli']
# Grup 12: ['delik' 'demir' 'deneme' 'deneyim' 'denge' 'deniz' 'depo' 'dere' 'dergi'
#  'deri' 'ders' 'dert' 'devlet' 'deyim' 'diken' 'dikiş' 'dindar' 'dinamik'
#  'dipnot' 'direk']
# Grup 13: ['direnç' 'disiplin' 'dizgin' 'doğal' 'doğru' 'doktor' 'dolap' 'dönüm'
#  'dostluk' 'dram' 'dua' 'dudak' 'düğün' 'dükkan' 'dünya' 'dürüst' 'düşman'
#  'düşünce' 'duygulu' 'düzen']
# Grup 14: ['ebleh' 'eczane' 'eğlence' 'ehliyet' 'ekmek' 'ekonomi' 'ekran' 'elbise'
#  'elektrik' 'elem' 'eleştiri' 'elma' 'emlak' 'enerji' 'engel' 'enginar'
#  'erkek' 'erozyon' 'eşek' 'eser']
# Grup 15: ['esinti' 'esir' 'eşit' 'espri' 'eşsiz' 'eşya' 'etken' 'evlat' 'evrak'
#  'evrensel' 'fabrika' 'faiz' 'fakirlik' 'faks' 'fani' 'fazlalık' 'felaket'
#  'festival' 'film' 'fincan']
# Grup 16: ['fizik' 'fındık' 'fırça' 'fobi' 'forma' 'formül' 'fotoğraf' 'fuar' 'füze'
#  'gaddar' 'garanti' 'garson' 'gazete' 'gece' 'geçerlik' 'geçit' 'gelenek'
#  'gelin' 'gemi' 'gençlik']
# Grup 17: ['genetik' 'gerçeklik' 'gezegen' 'gezgin' 'gezi' 'giyim' 'giysi' 'gizem'
#  'gizlilik' 'gıcırtı' 'gölet' 'gölge' 'gömlek' 'gönüllü' 'görev' 'görüntü'
#  'görüşme' 'gösterge' 'gözlük' 'gram']
# Grup 18: ['gravür' 'grev' 'güç' 'gül' 'gülüş' 'gün' 'gündüz' 'güneş' 'güney'
#  'gümüş' 'gurbet' 'gurultu' 'gürültü' 'gurur' 'güven' 'güzellik' 'haber'
#  'hacim' 'hain' 'hakim']
# Grup 19: ['haksızlık' 'hamile' 'hamur' 'haraç' 'harf' 'harika' 'harita' 'hasar'
#  'haşarı' 'hasret' 'hastane' 'hata' 'hava' 'havuç' 'havuz' 'hayat'
#  'haydut' 'hayret' 'hayta' 'hayvan']
# Grup 20: ['haz' 'hedef' 'hediye' 'hekim' 'heyecan' 'heykel' 'hikaye' 'his' 'hizmet'
#  'hırçınlık' 'hırdavat' 'hırs' 'hırsız' 'hısım' 'hormon' 'horultu'
#  'hoşnut' 'hücre' 'hukuk' 'huzur']
# Grup 21: ['hüzün' 'ibadet' 'ibare' 'iblis' 'ibraz' 'ibre' 'ibret' 'ibrik' 'içerik'
#  'içgüdü' 'içim' 'içki' 'içtenlik' 'idare' 'ideal' 'iğde' 'ihbar' 'ihmal'
#  'iklim' 'ilaç']
# Grup 22: ['ilave' 'ilgi' 'ilkbahar' 'imaj' 'imza' 'inanç' 'incir' 'indirim'
#  'insanlık' 'iplik' 'ipek' 'işaret' 'işçi' 'ishal' 'iskele' 'iskelet'
#  'işlemci' 'itiraz' 'ivme' 'iyilik']
# Grup 23: ['izlenim' 'ılık' 'ıslak' 'ıslık' 'ısrar' 'jimnastik' 'kabin' 'kablo'
#  'kaçak' 'kadeh' 'kadın' 'kafa' 'kafiye' 'kağıt' 'kahkaha' 'kahvaltı'
#  'kahve' 'kaldıraç' 'kalori' 'kalp']
# Grup 24: ['kambur' 'kamera' 'kamyon' 'kampus' 'kan' 'kanca' 'kanal' 'kanun' 'kapak'
#  'kapı' 'kaplama' 'kapüşon' 'karanlık' 'karar' 'kardeş' 'kargaşa' 'kargo'
#  'karınca' 'karşıt' 'karton']
# Grup 25: ['kas' 'kaşık' 'kaşıntı' 'kasnak' 'katil' 'katman' 'kavga' 'kaygan'
#  'kayıp' 'kayısı' 'kaza' 'kazanç' 'kelebek' 'kemik' 'kepenk' 'kerpeten'
#  'keyif' 'kimya' 'kimyon' 'kitap']
# Grup 26: ['kırık' 'kırmızı' 'kış' 'kışla' 'kısım' 'kıtlık' 'kız' 'koç' 'koku'
#  'kolonya' 'kolye' 'komedi' 'komplo' 'komşu' 'konak' 'konfor' 'konut'
#  'köprü' 'köpük' 'kopya']
# Grup 27: ['koridor' 'korku' 'koruma' 'köşk' 'koşu' 'köy' 'kral' 'krem' 'kucak'
#  'küfür' 'kulak' 'külhan' 'külot' 'kültür' 'kum' 'kural' 'kurnazlık' 'kuş'
#  'kuşku' 'kutu']
# Grup 28: ['kuvvet' 'kuyumcu' 'kuzgun' 'kuzu' 'lamba' 'lehçe' 'lezzet' 'liman'
#  'limon' 'lirik' 'lise' 'lokanta' 'lüks' 'maaş' 'madalya' 'madde' 'maden'
#  'mafya' 'mağara' 'mahkeme']
# Grup 29: ['makale' 'makas' 'makine' 'makyaj' 'manken' 'mantık' 'marangoz' 'marka'
#  'masa' 'matara' 'matematik' 'mayın' 'maytap' 'medya' 'mektup' 'melek'
#  'memur' 'merak' 'metal' 'mevsim']
# Grup 30: ['meyve' 'mezar' 'mide' 'minder' 'mineral' 'miras' 'misafir' 'mısra'
#  'mızrak' 'mızrap' 'mobilya' 'moda' 'monitör' 'monoton' 'moral' 'motor'
#  'muafiyet' 'müfettiş' 'müftülük' 'muhbir']
# Grup 31: ['mühendis' 'mülk' 'müşfik' 'muson' 'mutfak' 'mutluluk' 'muz' 'müzik'
#  'nakavt' 'nakil' 'namaz' 'namus' 'neden' 'nefes' 'nehir' 'nesil' 'nesne'
#  'neşe' 'nezle' 'nişancı']
# Grup 32: ['nöbet' 'noksan' 'ocak' 'odun' 'öğlen' 'öğrenci' 'oksijen' 'okul' 'okuma'
#  'olay' 'olgunluk' 'ölüm' 'omuz' 'öncülük' 'önem' 'onur' 'orman' 'örgüt'
#  'örnek' 'ortam']
# Grup 33: ['örtü' 'oruç' 'otlak' 'otel' 'otoban' 'otobüs' 'otorite' 'övgü' 'oynaş'
#  'oyun' 'özet' 'özgür' 'özlem' 'özür' 'özveri' 'palto' 'pamuk' 'pantolon'
#  'papatya' 'para']
# Grup 34: ['paragraf' 'parantez' 'parça' 'parke' 'parmak' 'paslı' 'pasta' 'paten'
#  'patik' 'patron' 'payda' 'pekmez' 'pembe' 'pencere' 'pense' 'peşinat'
#  'petrol' 'peynir' 'pide' 'pilav']
# Grup 35: ['pilot' 'pire' 'pirinç' 'pislik' 'piston' 'pıhtı' 'polis' 'pomat'
#  'prensip' 'protein' 'punto' 'pusu' 'radyo' 'radyum' 'rahat' 'rakam'
#  'rakip' 'reçel' 'refah' 'referans']
# Grup 36: ['rehber' 'reklam' 'resim' 'rezalet' 'roman' 'röfle' 'rüzgar' 'şebek'
#  'sabır' 'sadakat' 'sadist' 'şafak' 'sağlam' 'şahane' 'sahil'
#  'sahtekarlık' 'şair' 'sakal' 'sakatlık' 'saksı']
# Grup 37: ['sakinlik' 'salata' 'salon' 'şalter' 'şamata' 'şapka' 'sanatçı' 'sanayi'
#  'sancak' 'sandık' 'sanık' 'saray' 'şarkı' 'sarhoş' 'sarı' 'sarık' 'sarp'
#  'sarsıntı' 'satranç' 'saygı']
# Grup 38: ['sazlık' 'şebeke' 'sebze' 'seçmen' 'sefalet' 'şeffaf' 'şefkat' 'şeker'
#  'selam' 'semer' 'serbest' 'sergi' 'serin' 'serseri' 'ses' 'sesteş'
#  'sevap' 'sevgi' 'sevgili' 'sevinç']
# Grup 39: ['seyahat' 'seyirci' 'sezon' 'sicil' 'şiddetli' 'şiir' 'sigara' 'sinema'
#  'sinirlilik' 'sinsi' 'sistem' 'siyah' 'sıcaklık' 'sığınak' 'sığlık'
#  'sıkışık' 'sıkıntı' 'sınav' 'sınıf' 'sırdaş']
# Grup 40: ['slogan' 'soba' 'sofra' 'soğan' 'soğuk' 'sohbet' 'şok' 'solo' 'somut'
#  'sonbahar' 'sondaj' 'sonsuz' 'sörf' 'soru' 'sorumluluk' 'sorun' 'sos'
#  'soytarı' 'soyut' 'söz']
# Grup 41: ['sözcük' 'sözlük' 'spor' 'standart' 'suçlu' 'sulak' 'sülün' 'süngü'
#  'şüphe' 'süre' 'sürpriz' 'süt' 'sütlaç' 'tabaka' 'taban' 'tabanca' 'tabu'
#  'tabure' 'tahta' 'takas']
# Grup 42: ['takı' 'takım' 'takip' 'taklit' 'takoz' 'taksi' 'taksit' 'tamirat' 'tane'
#  'tanıtım' 'tansiyon' 'tarak' 'tarih' 'tarla' 'taşıt' 'tatil' 'tatlı'
#  'tavuk' 'taze' 'tehlike']
# Grup 43: ['teke' 'tekel' 'tekerlek' 'tekerleme' 'tekme' 'tekne' 'tekrar' 'telaş'
#  'televizyon' 'temas' 'temiz' 'tenis' 'tepsi' 'ter' 'terazi' 'terlik'
#  'terslik' 'tilki' 'tiryaki' 'titiz']
# Grup 44: ['tiyatro' 'tıknaz' 'tıp' 'tırnak' 'tırtık' 'tokat' 'tokluk' 'toplum'
#  'toprak' 'topuk' 'torba' 'tören' 'tornavida' 'tortu' 'toz' 'trafik'
#  'tren' 'tuhaflık' 'tüketim' 'turizm']
# Grup 45: ['tutku' 'tütün' 'tüy' 'uçak' 'ücra' 'ücret' 'uçuş' 'üfürük' 'uğultu'
#  'uğur' 'ulaşım' 'ülke' 'ülkü' 'ülser' 'ümit' 'ünite' 'ünlem' 'ünlü'
#  'üretici' 'urgan']
# Grup 46: ['üşenme' 'ütopya' 'uyarı' 'uygarlık' 'uygunluk' 'uyku' 'uyum' 'uzak'
#  'uzay' 'üzüm' 'uzunluk' 'üzüntü' 'vali' 'varlık' 'varoluş' 'vatan'
#  'vicdan' 'virüs' 'viski' 'vites']
# Grup 47: ['vitrin' 'vücut' 'yağcılık' 'yağış' 'yağmur' 'yakınlık' 'yakıt' 'yalan'
#  'yalı' 'yalnızlık' 'yama' 'yangın' 'yanık' 'yara' 'yardım' 'yarım'
#  'yarış' 'yastık' 'yaşlılık' 'yatak']
# Grup 48: ['yatkın' 'yatsı' 'yavru' 'yazar' 'yazı' 'yazlık' 'yemek' 'yenilik'
#  'yetenek' 'yeşil' 'yiyecek' 'yoga' 'yoğurt' 'yoksulluk' 'yolculuk'
#  'yonca' 'yorgunluk' 'yorum' 'yörünge' 'yuva']
# Grup 49: ['yüce' 'yürüyüş' 'yüzsüz' 'yüzük' 'zakkum' 'zalimlik' 'zaman' 'zanaat'
#  'zarar' 'zayıflık' 'zehir' 'zeka' 'zemin' 'zenginlik' 'zevk' 'zeytin'
#  'zihin' 'zincir' 'zılgıt' 'zıpkın']
# Grup 50: ['zorluk']
